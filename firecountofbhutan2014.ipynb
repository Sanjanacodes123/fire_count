# %%
#importing libraries
import numpy as np
import pandas as pd

#importing data
data_2014 = pd.read_csv("fire_archive_M-C61_2014 - copy.csv")
data_2014

#confidence level >= 80
conf_lvl = data_2014[data_2014["confidence"] >= 80].copy()
conf_lvl

#firecount of each month
fire_count = 

#frp > than 70
frp70 = conf_lvl[conf_lvl["frp"] > 70][["acq_date", "latitude", "longitude"]]
print(frp70)
# Out:
#   Cell In[5], line 14
#     fire_count =
#                  ^
# SyntaxError: invalid syntax
