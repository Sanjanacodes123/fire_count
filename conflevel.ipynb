# %%
import numpy as np
import pandas as pd

data_2014 = pd.read_csv("fire_archive_M-C61_2014 - Copy.csv")

#confidence level >80
conf_lvl = data_2014[data_2014["confidence"] >= 80].copy()
print(conf_lvl)
# Out:
#      latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 15    26.7764    90.8551       337.0   1.1    1.0  2014-02-01       709
# 20    27.6831    89.4622       325.1   1.2    1.1  2014-02-01       710
# 21    27.6812    89.4507       389.6   1.2    1.1  2014-02-01       710
# 29    26.8800    91.9563       346.0   1.3    1.1  2014-02-03       657
# 32    27.0552    90.9502       320.7   1.5    1.2  2014-02-03       657
# ..        ...        ...         ...   ...    ...         ...       ...
# 404   28.0898    90.1684       331.6   1.6    1.2  2014-12-20       657
# 405   28.0931    90.1873       320.7   1.6    1.2  2014-12-20       657
# 406   27.4357    91.1635       329.6   1.0    1.0  2014-12-25       715
# 410   27.4349    89.6397       359.2   1.0    1.0  2014-12-25       716
# 417   26.9026    90.3696       321.1   1.4    1.2  2014-12-30       734
#
#     satellite instrument  confidence  version  bright_t31    frp daynight  \
# 15       Aqua      MODIS          89     6.03       301.8   36.0        D
# 20       Aqua      MODIS          83     6.03       286.7   29.2        D
# 21       Aqua      MODIS         100     6.03       298.0  246.9        D
# 29       Aqua      MODIS          94     6.03       300.9   72.3        D
# 32       Aqua      MODIS          80     6.03       293.1   30.2        D
# ..        ...        ...         ...      ...         ...    ...      ...
# 404      Aqua      MODIS          87     6.03       283.2   62.1        D
# 405      Aqua      MODIS          80     6.03       280.2   38.3        D
# 406      Aqua      MODIS          86     6.03       293.1   28.0        D
# 410      Aqua      MODIS          99     6.03       302.2   86.8        D
# 417      Aqua      MODIS          80     6.03       302.3   24.5        D
#
#      type
# 15      0
# 20      0
# 21      0
# 29      0
# 32      0
# ..    ...
# 404     0
# 405     0
# 406     0
# 410     0
# 417     0
#
# [111 rows x 15 columns]
